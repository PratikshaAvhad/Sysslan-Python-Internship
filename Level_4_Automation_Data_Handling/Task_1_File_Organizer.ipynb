# %% [markdown]
# # Task 1: File Organizer

# %%
import os
import shutil

# Folder containing files to organize
source_folder = "files"

# File type categories
file_types = {
    "Images": [".jpg", ".jpeg", ".png", ".gif"],
    "Documents": [".pdf", ".docx", ".txt"],
    "Videos": [".mp4", ".avi", ".mkv"]
}

# Create category folders
for folder in file_types:
    os.makedirs(os.path.join(source_folder, folder), exist_ok=True)

# Organize files
for file in os.listdir(source_folder):
    file_path = os.path.join(source_folder, file)

    if os.path.isfile(file_path):
        extension = os.path.splitext(file)[1].lower()

        for folder, extensions in file_types.items():
            if extension in extensions:
                shutil.move(file_path, os.path.join(source_folder, folder, file))
                break

print("Files organized successfully.")
# Out:
# Files organized successfully.

# %% [markdown]
# ## Objective
# Organize files into separate folders based on their file types.
#
# ## Description
# The program checks the file extensions in a folder and moves
# files into separate folders such as Images, Documents, and Videos.
#
# ## Concepts Used
# - File handling
# - `os` module
# - File extensions
# - Folder creation
# - File moving
# - Conditional statements
# - Loops
#
# ## Important Functions Used
# - `os.listdir()` → folder मधल्या files पाहतो
# - `os.path.splitext()` → file extension शोधतो
# - `os.makedirs()` → folders तयार करतो
# - `shutil.move()` → file योग्य folder मध्ये move करतो
#
# ## Before Running
# Create a folder named `files` in the same location as the notebook.
#
# Add some sample files inside it, such as:
# - `photo.jpg`
# - `notes.txt`
# - `document.pdf`
# - `video.mp4`
